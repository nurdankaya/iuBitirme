# %% [markdown]
# ### Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %% [markdown]
# ### Fetch Data

# %%
directory="./dataset"

# %%
batch_size = 16
img_height = 180
img_width = 180

# %% [markdown]
# tf.keras.preprocessing.image_dataset_from_directory kullanarak görüntü veri kümemizi direkt olarak herhangi bir dizinden okutabiliriz. Bu fonksiyon dizindeki görüntü dosyalarından bir tf.data.Dataset oluşturur.

# %% [markdown]
# Bu fonksiyon ile desteklenen resim formatları: jpeg, png, bmp, gif’dir. Animasyonlu gifler ilk kareye kesilir.

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  directory,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 324 files belonging to 3 classes.
# Using 260 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  directory,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 324 files belonging to 3 classes.
# Using 64 files for validation.

# %% [markdown]
# Bu tf.data.Dataset nesnesi her seferinde 32 tane (180 x 180) boyutlu görüntüyü size geri döndürecektir çünkü batch_size = 32 olarak ayarlanmıştır.

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (16, 180, 180, 3)
# (16,)

# %%
train_ds.class_names
# Out:
# ['diger', 'nesih', 'rika']

# %% [markdown]
# Veri kümesini Görüntüleyelim:

# %% [markdown]
# Burada .take(1) alındığı için 1 adet 32 büyüklüğünde yığın seçilecektir.

# %%
class_names = train_ds.class_names

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i].numpy().argmax()])
        plt.axis("off")

# %% [markdown]
# ### Training

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
normalization_layer = layers.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 0.99704325

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %%
num_classes = 3

model = Sequential([
    data_augmentation,
    layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
    layers.Conv2D(16, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(num_classes)
])

# %% [markdown]
# data augmentation:görüntü verisi çeşitlendirme

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 180, 180, 3)       0
# _________________________________________________________________
# rescaling_1 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 180, 180, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 90, 90, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 90, 90, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 30976)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               3965056
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 3,989,027
# Trainable params: 3,989,027
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 17/17 [==============================] - 5s 239ms/step - loss: 1.1372 - accuracy: 0.4615 - val_loss: 1.0836 - val_accuracy: 0.3750
# Epoch 2/30
# 17/17 [==============================] - 3s 183ms/step - loss: 0.9650 - accuracy: 0.4500 - val_loss: 0.9340 - val_accuracy: 0.5625
# Epoch 3/30
# 17/17 [==============================] - 3s 183ms/step - loss: 0.8526 - accuracy: 0.5577 - val_loss: 1.1152 - val_accuracy: 0.6406
# Epoch 4/30
# 17/17 [==============================] - 3s 182ms/step - loss: 0.7979 - accuracy: 0.6231 - val_loss: 1.1397 - val_accuracy: 0.5781
# Epoch 5/30
# 17/17 [==============================] - 4s 216ms/step - loss: 0.6547 - accuracy: 0.6885 - val_loss: 1.1440 - val_accuracy: 0.6250
# Epoch 6/30
# 17/17 [==============================] - 3s 183ms/step - loss: 0.6909 - accuracy: 0.7385 - val_loss: 1.0446 - val_accuracy: 0.5469
# Epoch 7/30
# 17/17 [==============================] - 3s 190ms/step - loss: 0.5671 - accuracy: 0.8038 - val_loss: 1.1399 - val_accuracy: 0.5781
# Epoch 8/30
# 17/17 [==============================] - 3s 184ms/step - loss: 0.5003 - accuracy: 0.8115 - val_loss: 0.9380 - val_accuracy: 0.6562
# Epoch 9/30
# 17/17 [==============================] - 3s 182ms/step - loss: 0.4484 - accuracy: 0.8192 - val_loss: 2.2549 - val_accuracy: 0.5469
# Epoch 10/30
# 17/17 [==============================] - 3s 186ms/step - loss: 0.5350 - accuracy: 0.8077 - val_loss: 1.9396 - val_accuracy: 0.5312
# Epoch 11/30
# 17/17 [==============================] - 3s 184ms/step - loss: 0.3868 - accuracy: 0.8423 - val_loss: 1.1520 - val_accuracy: 0.7031
# Epoch 12/30
# 17/17 [==============================] - 3s 183ms/step - loss: 0.3326 - accuracy: 0.8846 - val_loss: 2.8920 - val_accuracy: 0.5469
# Epoch 13/30
# 17/17 [==============================] - 3s 180ms/step - loss: 0.3968 - accuracy: 0.8500 - val_loss: 1.0305 - val_accuracy: 0.7031
# Epoch 14/30
# 17/17 [==============================] - 3s 182ms/step - loss: 0.4183 - accuracy: 0.8538 - val_loss: 1.8012 - val_accuracy: 0.5312
# Epoch 15/30
# 17/17 [==============================] - 3s 185ms/step - loss: 0.3890 - accuracy: 0.8423 - val_loss: 2.1977 - val_accuracy: 0.6250
# Epoch 16/30
# 17/17 [==============================] - 3s 191ms/step - loss: 0.4312 - accuracy: 0.8346 - val_loss: 1.7261 - val_accuracy: 0.5000
# Epoch 17/30
# 17/17 [==============================] - 3s 185ms/step - loss: 0.3164 - accuracy: 0.8846 - val_loss: 1.4749 - val_accuracy: 0.5312
# Epoch 18/30
# 17/17 [==============================] - 3s 185ms/step - loss: 0.2610 - accuracy: 0.8962 - val_loss: 1.6021 - val_accuracy: 0.5781
# Epoch 19/30
# 17/17 [==============================] - 3s 183ms/step - loss: 0.2437 - accuracy: 0.9000 - val_loss: 3.2246 - val_accuracy: 0.5312
# Epoch 20/30
# 17/17 [==============================] - 3s 185ms/step - loss: 0.2638 - accuracy: 0.9000 - val_loss: 1.1459 - val_accuracy: 0.7188
# Epoch 21/30
# 17/17 [==============================] - 3s 182ms/step - loss: 0.3393 - accuracy: 0.8808 - val_loss: 1.2784 - val_accuracy: 0.6719
# Epoch 22/30
# 17/17 [==============================] - 3s 185ms/step - loss: 0.2598 - accuracy: 0.8808 - val_loss: 2.0841 - val_accuracy: 0.5312
# Epoch 23/30
# 17/17 [==============================] - 3s 183ms/step - loss: 0.2885 - accuracy: 0.9038 - val_loss: 1.9921 - val_accuracy: 0.5781
# Epoch 24/30
# 17/17 [==============================] - 3s 186ms/step - loss: 0.2521 - accuracy: 0.8808 - val_loss: 1.6275 - val_accuracy: 0.6094
# Epoch 25/30
# 17/17 [==============================] - 3s 183ms/step - loss: 0.1867 - accuracy: 0.9154 - val_loss: 2.5576 - val_accuracy: 0.4844
# Epoch 26/30
# 17/17 [==============================] - 3s 186ms/step - loss: 0.2485 - accuracy: 0.8846 - val_loss: 0.7330 - val_accuracy: 0.8281
# Epoch 27/30
# 17/17 [==============================] - 3s 182ms/step - loss: 0.3875 - accuracy: 0.8346 - val_loss: 0.8266 - val_accuracy: 0.7969
# Epoch 28/30
# 17/17 [==============================] - 3s 183ms/step - loss: 0.2122 - accuracy: 0.9231 - val_loss: 2.1444 - val_accuracy: 0.5156
# Epoch 29/30
# 17/17 [==============================] - 3s 186ms/step - loss: 0.2137 - accuracy: 0.9077 - val_loss: 3.6356 - val_accuracy: 0.4844
# Epoch 30/30
# 17/17 [==============================] - 3s 183ms/step - loss: 0.1628 - accuracy: 0.9269 - val_loss: 2.0925 - val_accuracy: 0.5469

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ### Predict

# %%
import os

directoryLabel="./test/"
os.chdir(directoryLabel)
testLabels=os.listdir()

for label in testLabels:
    directoryData="./test/"+label+"/"
    accuracyCount=0
    dataCount=0

    os.chdir(directoryData)
    testData=os.listdir()

    for data in testData:
        dataCount=dataCount+1
       
        img = tf.keras.utils.load_img(
            data, target_size=(img_height, img_width)
        )
        img_array = tf.keras.utils.img_to_array(img)
        img_array = tf.expand_dims(img_array, 0) # Create a batch
        
        predictions = model.predict(img_array)
        score = tf.nn.softmax(predictions[0])
        if class_names[np.argmax(score)]==label:
            accuracyCount=accuracyCount+1
        
        #print(
        #   "This image {} most likely belongs to {} with a {:.2f} percent confidence."
        #   .format(data,class_names[np.argmax(score)], 100 * np.max(score)))
        #
    print("{} türünden {} tane veriden {} tanesi doğru tahmin edildi ".format(label,dataCount,accuracyCount))
# Out:
# nesih türünden 5 tane veriden 0 tanesi doğru tahmin edildi

# %% [markdown]
# https://www.tensorflow.org/tutorials/images/classification
